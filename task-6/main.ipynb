# %%
import pandas as pd
df=pd.read_csv('manufacturing_defect_dataset.csv')
df
# Out:
#       ProductionVolume  ProductionCost  SupplierQuality  DeliveryDelay  \
# 0                  202    13175.403783        86.648534              1
# 1                  535    19770.046093        86.310664              4
# 2                  960    19060.820997        82.132472              0
# 3                  370     5647.606037        87.335966              5
# 4                  206     7472.222236        81.989893              3
# ...                ...             ...              ...            ...
# 3235               762    11325.689263        89.252385              2
# 3236               335     5598.837988        95.701437              4
# 3237               835    11736.177712        96.431554              5
# 3238               302    13664.196210        91.089782              1
# 3239               355    13563.605806        83.595956              2
#
#       DefectRate  QualityScore  MaintenanceHours  DowntimePercentage  \
# ...

# %%
#  'ProductionVolume', 'ProductionCost', 'SupplierQuality', 'QualityScore', 'MaintenanceHours', 'DowntimePercentage', 'WorkerProductivity',DecfectStatus use only this columns and remove the rest of the columns
columns_to_keep = ['ProductionVolume', 'ProductionCost', 'SupplierQuality', 'QualityScore', 'MaintenanceHours', 'DowntimePercentage', 'WorkerProductivity', 'DefectStatus']
df = df[columns_to_keep]
df
# Out:
#       ProductionVolume  ProductionCost  SupplierQuality  QualityScore  \
# 0                  202    13175.403783        86.648534     63.463494
# 1                  535    19770.046093        86.310664     83.697818
# 2                  960    19060.820997        82.132472     90.350550
# 3                  370     5647.606037        87.335966     67.628690
# 4                  206     7472.222236        81.989893     82.728334
# ...                ...             ...              ...           ...
# 3235               762    11325.689263        89.252385     87.141681
# 3236               335     5598.837988        95.701437     95.562997
# 3237               835    11736.177712        96.431554     77.973442
# 3238               302    13664.196210        91.089782     95.755591
# 3239               355    13563.605806        83.595956     94.630965
#
#       MaintenanceHours  DowntimePercentage  WorkerProductivity  DefectStatus
# ...

# %%
df.isnull().sum()
# Out:
# ProductionVolume      0
# ProductionCost        0
# SupplierQuality       0
# QualityScore          0
# MaintenanceHours      0
# DowntimePercentage    0
# WorkerProductivity    0
# DefectStatus          0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(df)
# Out:
# <Axes: >

# %%
x=df.drop('DefectStatus',axis=1)
y=df['DefectStatus']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# use xg boost classifier
# %pip install xgboost
from xgboost import XGBClassifier
model=XGBClassifier()
